# %%
print(
        """
    Sveiki, jūs naudojatės programa sudaryti pirkinių krepšeliui.
    Pasirinkite programos funkciją:    
    1 - pasirikti produkta i krepseli
    2 - produkto kaina
    3 - kcal
    4 - galiojimo laikas
    0 - exit, iseiti is ciklo

    """
          
    )
# Out:
#     Sveiki, jūs naudojatės programa sudaryti pirkinių krepšeliui.
#     Pasirinkite programos funkciją:
#     1 - pasirikti produkta i krepseli
#     2 - produkto kaina
#     3 - kcal
#     4 - galiojimo laikas
#     0 - exit, iseiti is ciklo
